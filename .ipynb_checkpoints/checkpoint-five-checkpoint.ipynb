# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
# import pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 


# create your data frames using .read_csv 
highest_vc = pd.read_csv(r'C:\Users\timle\GitHub\Data_Sets\Serial_Killers\Highest_victim_count.csv')

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
# Using pairplot we'll visualize the data for correlation
sns.pairplot(highest_vc, x_vars=['Proven victims', 'Years active'], 
             y_vars='Name', size=6, aspect=2, kind='scatter')
plt.show()
# Out:
# C:\Users\timle\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#heatmap of highest_vc data
sns.heatmap(highest_vc.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %%
# Step 1 is to assign your x and y
# assign our feature variable/column TV as X and our target variable Sales as y
X = highest_vc['Name']
y = highest_vc['Proven victims']

# %%
# Step 2 is to create your train and test sets

# Splitting the varaibles as training and testing
# split the data by importing train_test_split from the sklearn.model_selection library
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
X_train
# Out:
# 0                     Luis Garavito
# 26                        Ted Bundy
# 12                   Ivan Maleshoff
# 11               Anatoly Onoprienko
# 4            Daniel Camargo Barbosa
# 28                  John Wayne Gacy
# 27              Clementine Barnabet
# 17                       Wang Qiang
# 29             Ali Asghar Borujerdi
# 14                    Willy Pickton
# 22                     Serhiy Tkach
# 32      Ramadan Abdel Rehim Mansour
# 21                    Moses Sithole
# 2                       Javed Iqbal
# 20    Tiago Henrique Gomes da Rocha
# 10                 Andrei Chikatilo
# 16             Alexander Pichushkin
# 15                     Gary Ridgway
# 23              Gennady Mikhasevich
# 7                       Yang Xinhai
# 3                    Mikhail Popkov
# 24            Hadj Mohammed Mesfewi
# 8                     Samuel Little
# Name: Name, dtype: object

# %%
y_train
# Out:
# 0     138
# 26     35
# 12     50
# 11     52
# 4      72
# 28     33
# 27     35
# 17     45
# 29     33
# 14     49
# 22     36
# 32     32
# 21     38
# 2     100
# 20     39
# 10     53
# 16     48
# 15     49
# 23     36
# 7      67
# 3      83
# 24     36
# 8      60
# Name: Proven victims, dtype: int64

# %%
# Step 3 is to build the model. Remember to import any libraries you may need
# Importing Statsmodels.api library from Stamodel package
import statsmodels.api as sm

# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

# %%
# Fitting the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()

# Printing the parameters
lr.params


# Not sure I can make this work considering I don't have more variables to utilize for making the linear-regression visual
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_71608/747902678.py in <module>
#       1 # Fitting the resgression line using 'OLS'
# ----> 2 lr = sm.OLS(y_train, X_train_sm).fit()
#       3
#       4 # Printing the parameters
#       5 lr.params
#
# ~\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.638    n/a
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was not particularly effective in this case.     I do not feel it was effective in this situation
# 3. Was your plot of the error terms a bell curve? Not really     n/a
